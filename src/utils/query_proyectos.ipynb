# %%
query = '''
INSERT INTO PROYECTOS (nombre_proyecto, id_vertical) VALUES
('Proyecto_HLF', '1'),
('Proyecto_EDA', '1'),
('Proyecto_BBDD', '1'),
('Proyecto_ML', '1'),
('Proyecto_Deployment', '1'),
('Proyecto_WebDev', '2'),
('Proyecto_Frontend', '2'),
('Proyecto_Backend', '2'),
('Proyecto_React', '2'),
('Proyecto_FullStack', '2');
'''
