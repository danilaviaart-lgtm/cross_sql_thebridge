# %%
query = '''
INSERT INTO PROYECTOS (id_proyecto, nombre_proyecto, id_vertical) VALUES
(1, 'Proyecto_HLF, '1'),
(2, 'Proyecto_EDA', '1'),
(3, 'Proyecto_BBDD', '1'),
(4, 'Proyecto_ML', '1'),
(5, 'Proyecto_Deployment', '1'),
(6, 'Proyecto_WebDev', '2'),
(7, 'Proyecto_Frontend', '2'),
(8, 'Proyecto_Backend', '2'),
(9, 'Proyecto_React', '2'),
(10, 'Proyecto_FullStack', '2');
'''
