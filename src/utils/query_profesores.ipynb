# %%
query = '''
INSERT INTO PROFESORES (id_profesor, nombre, rol, modalidad, id_promocion) VALUES
(1, 'Noa Yáñez', 'TA', 'Presencial', 1),
(2, 'Saturnina Benitez', 'TA', 'Presencial', 1),
(3, 'Anna Feliu', 'TA', 'Presencial', 3),
(4, 'Rosalva Ayuso', 'TA', 'Presencial', 5),
(5, 'Ana Sofia Ferrer', 'TA', 'Presencial', 4),
(6, 'Angelica Corral', 'TA', 'Presencial', 2),
(7, 'Ariel Lledo', 'TA', 'Presencial', 1),
(8, 'Mario Prats', 'LI', 'Online', 4),
(9, 'Luis Angel Suarez', 'LI', 'Online', 3),
(10, 'Maria Dolores Diaz', 'LI', 'Online', 1)

'''
