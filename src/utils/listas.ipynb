# %%
#Listas

list_proyectos = [
    "HLF",
    "EDA",
    "BBDD",
    "ML",
    "Deployment",
    "WebDev",
    "Frontend",
    "Backend",
    "React",
    "FullStack"
]

list_campus = [
    "Madrid",
    "Valencia"
]

list_verticales = [
    "Data Science",
    "Full Stack"
]
