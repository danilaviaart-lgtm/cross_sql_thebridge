# %%
query = '''
INSERT INTO promocion (nombre_mes, fecha_comienzo, id_campus, id_vertical) VALUES
('Septiembre', '18/09/2023', 1, 1),
('Febrero', '12/02/2024', 1, 1),
('Septiembre', '18/09/2023', 1, 2),
('Febrero', '12/02/2024', 2, 2),
('Septiembre', '12/09/2024', 2, 2);
'''
